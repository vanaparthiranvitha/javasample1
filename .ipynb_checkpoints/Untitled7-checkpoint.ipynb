# %%
str1="python is a programming language"
str2=str1.split()
print(str1);print(str2)
str1="python,is,a,programming,language"
str2=str1.split(sep=',')
print(str1);print(str2)
# Out:
# python is a programming language
# ['python', 'is', 'a', 'programming', 'language']
# python,is,a,programming,language
# ['python', 'is', 'a', 'programming', 'language']
