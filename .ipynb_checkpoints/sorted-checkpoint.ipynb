# %%
num=[1,2,3,4,5,6]
print("length of list:",len (num))
# Out:
# length of list: 6

# %%
list=[1,2,3,4,5,6]
list=['java','c','python','cpp']
print("max of list 1:",min(list))
print("max of list 2:",min(list))
# Out:
# max of list 1: c
# max of list 2: c

# %%
list1=[1,2,3,4,5,6]
list2=['java','c','python','cpp']
print("min of list 1:",min(list1))
print("min of list 2:",min(list2))
# Out:
# min of list 1: 1
# min of list 2: c

# %%
list1=[1,2,3,4,5,6]
print("sum of list items:",sum(list1))
# Out:
# sum of list items: 21

# %%
str="python"
list1=list(str)
print(list1)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
num=[1,2,3,4,6,5]
lang=['java','c','python','cpp']
print(sorted(num))
print(sorted(lang))
# Out:
# [1, 2, 3, 4, 5, 6]
# ['c', 'cpp', 'java', 'python']
