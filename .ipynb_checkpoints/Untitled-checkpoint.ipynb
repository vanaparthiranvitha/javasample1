# %%
print("ranvitha")
# Out:
# ranvitha

# %%
print("kamala institute of technology and science")
# Out:
# kamala institute of technology and science

# %%
print("ranvitha")
print("srinivas")
print("srilatha")
print("ram charan")
print("keshavapatnam")
# Out:
# ranvitha
# srinivas
# srilatha
# ram charan
# keshavapatnam
