# %%
x=10
print(x)
# Out:
# 10

# %%
print("the value of variable is",+x)
print("x=",x)
print("%d" %x)
x=10
print("the value of variable is",(x))
# Out:
# the value of variable is 10
# x= 10
# 10
# the value of variable is 10
