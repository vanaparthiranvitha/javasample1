# %%
 i=1;
sum=0
n=int(input("ente n"))
for 1 in range(1,n+1):
        sum=sum+i
        print(sum)
# Out:
#   Cell In[6], line 4
#     for 1 in range(1,n+1):
#         ^
# SyntaxError: cannot assign to literal
