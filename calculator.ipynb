# %%
def calculator():
    print("simple calculator")
    print("select operation") 
    print("1.add")
    print("2.subtract")
    print("3.multiply")
    print("4.divide")
choice=int(input("enter choice(1/2/3/4):"))
if choice not in[1,2,3,4]:
    print("invalid choice.please select a valid operation.")
num1=float(input("enter the first number:"))
num2=float(input("enter the second number:"))
if choice==1:
            print(f"the result is:{num1+num2}")
elif choice==2:
            print(f"the result is:{num-num2}")
elif choice==3:
            print(f"the result is:{num*num2}")
elif choice==4:
            if num2==0:
                 print("error:division by zero is not allowed.")
            else:
                print(f"the result:{num1/num2}")
# Out:
# enter choice(1/2/3/4): 1
# enter the first number: 10
# enter the second number: 20
# the result is:30.0

# %%
def calculator():
    print("simple calculator")
    print("select operation") 
    print("1.add")
    print("2.subtract")
    print("3.multiply")
    print("4.divide")
choice=int(input("enter choice(1/2/3/4):"))
if choice not in[1,2,3,4]:
    print("invalid choice.please select a valid operation.")
num1=float(input("enter the first number:"))
num2=float(input("enter the second number:"))
if choice==1:
            print(f"the result is:{num1+num2}")
elif choice==2:
            print(f"the result is:{num-num2}")
elif choice==3:
            print(f"the result is:{num*num2}")
elif choice==4:
            if num2==0:
                 print("error:division by zero is not allowed.")
            else:
                print(f"the result:{num1/num2}")
# Out:
# enter choice(1/2/3/4): 2
# enter the first number: 3
# enter the second number: 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#      14             print(f"the result is:{num1+num2}")
#      15 elif choice==2:
# ---> 16             print(f"the result is:{num-num2}")
#      17 elif choice==3:
#      18             print(f"the result is:{num*num2}")
#
# NameError: name 'num' is not defined

# %%
def calculator():
    print("simple calculator")
    print("select operation") 
    print("1.add")
    print("2.subtract")
    print("3.multiply")
    print("4.divide")
choice=int(input("enter choice(1/2/3/4):"))
if choice not in[1,2,3,4]:
    print("invalid choice.please select a valid operation.")
num1=float(input("enter the first number:"))
num2=float(input("enter the second number:"))
if choice==1:
            print(f"the result is:{num1+num2}")
elif choice==2:
            print(f"the result is:{num-num2}")
elif choice==3:
            print(f"the result is:{num*num2}")
elif choice==4:
            if num2==0:
                 print("error:division by zero is not allowed.")
            else:
                print(f"the result:{num1/num2}")
# Out:
# enter choice(1/2/3/4): 3
# enter the first number: 30
# enter the second number: 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 18
#      16             print(f"the result is:{num-num2}")
#      17 elif choice==3:
# ---> 18             print(f"the result is:{num*num2}")
#      19 elif choice==4:
#      20             if num2==0:
#
# NameError: name 'num' is not defined
